# %%
import pandas as pd

datos = pd.read_csv("Medicaldataset.csv")

datos.head(1000)
# Out:
#      Age  Gender  Heart rate  Systolic blood pressure  \
# 0     63       1          66                      160
# 1     20       1          94                       98
# 2     56       1          64                      160
# 3     66       1          70                      120
# 4     54       1          64                      112
# ..   ...     ...         ...                      ...
# 995   32       1          40                      179
# 996   63       0          60                      214
# 997   86       1          60                      154
# 998   40       0          61                      160
# 999   29       0          74                      223
#
#      Diastolic blood pressure  Blood sugar   CK-MB  Troponin    Result
# 0                          83        160.0    1.80     0.012  negative
# 1                          46        296.0    6.75     1.060  positive
# 2                          77        270.0    1.99     0.003  negative
# ...

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1319 entries, 0 to 1318
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1319 non-null   int64
#  1   Gender                    1319 non-null   int64
#  2   Heart rate                1319 non-null   int64
#  3   Systolic blood pressure   1319 non-null   int64
#  4   Diastolic blood pressure  1319 non-null   int64
#  5   Blood sugar               1319 non-null   float64
#  6   CK-MB                     1319 non-null   float64
#  7   Troponin                  1319 non-null   float64
#  8   Result                    1319 non-null   object
# dtypes: float64(3), int64(5), object(1)
# memory usage: 92.9+ KB

# %%
datos.describe()
# Out:
#                Age       Gender   Heart rate  Systolic blood pressure  \
# count  1319.000000  1319.000000  1319.000000              1319.000000
# mean     56.193328     0.659591    78.336619               127.170584
# std      13.638173     0.474027    51.630270                26.122720
# min      14.000000     0.000000    20.000000                42.000000
# 25%      47.000000     0.000000    64.000000               110.000000
# 50%      58.000000     1.000000    74.000000               124.000000
# 75%      65.000000     1.000000    85.000000               143.000000
# max     103.000000     1.000000  1111.000000               223.000000
#
#        Diastolic blood pressure  Blood sugar        CK-MB     Troponin
# count               1319.000000  1319.000000  1319.000000  1319.000000
# mean                  72.269143   146.634344    15.274306     0.360942
# std                   14.033924    74.923045    46.327083     1.154568
# ...

# %%
Hombres = datos[datos["Gender"] == 1]
Hombres.count()
# Out:
# Age                         870
# Gender                      870
# Heart rate                  870
# Systolic blood pressure     870
# Diastolic blood pressure    870
# Blood sugar                 870
# CK-MB                       870
# Troponin                    870
# Result                      870
# dtype: int64

# %%
Mujeres = datos[datos["Gender"]== 0]
Mujeres.count()
# Out:
# Age                         449
# Gender                      449
# Heart rate                  449
# Systolic blood pressure     449
# Diastolic blood pressure    449
# Blood sugar                 449
# CK-MB                       449
# Troponin                    449
# Result                      449
# dtype: int64

# %%
datos.corr()
# Out:
# <ipython-input-35-616d89d74c02>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos.corr()
#                                Age    Gender  Heart rate  \
# Age                       1.000000 -0.093560   -0.023655
# Gender                   -0.093560  1.000000   -0.026781
# Heart rate               -0.023655 -0.026781    1.000000
# Systolic blood pressure   0.018231  0.011065    0.010882
# Diastolic blood pressure  0.002812 -0.009370    0.108353
# Blood sugar              -0.004007  0.006668   -0.019584
# CK-MB                     0.017700  0.017527   -0.013001
# Troponin                  0.088557  0.065793    0.011180
#
#                           Systolic blood pressure  Diastolic blood pressure  \
# Age                                      0.018231                  0.002812
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numericals = ["Age", "Heart rate", "Systolic blood pressure",
             "Diastolic blood pressure", "Blood sugar", "CK-MB",
             "Troponin"]

sns.pairplot(datos, vars=numericals, hue="Result")
plt.show()

# %%
categoricals = ["Gender", "Result"]
for i in categoricals:
    fig, axes = plt.subplots(nrows=1, ncols=7, figsize=(15, 5))
    for j, k in enumerate(numericals):
        sns.boxplot(datos, y=k, x=i, ax=axes[j])
    plt.tight_layout()
    plt.show()

# %%
#Vamos a cambiar las etiquetas en Results
import numpy as np
import plotly.express as px

from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.neighbors import KNeighborsClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

LabelEncoder()
datos["Result"] = LabelEncoder().fit_transform(datos["Result"])

# %%
#vamos a escarlar los valores
X = datos.iloc[:, :-1].values
y = datos.iloc[: ,-1].values



scaler = MinMaxScaler()
X = scaler.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, test_size=0.2)
X
# Out:
# array([[5.50561798e-01, 1.00000000e+00, 4.21631531e-02, ...,
#         2.47035573e-01, 4.93528075e-03, 1.06806486e-03],
#        [6.74157303e-02, 1.00000000e+00, 6.78276810e-02, ...,
#         5.15810277e-01, 2.14529547e-02, 1.02825517e-01],
#        [4.71910112e-01, 1.00000000e+00, 4.03299725e-02, ...,
#         4.64426877e-01, 5.56929248e-03, 1.94193611e-04],
#        ...,
#        [3.48314607e-01, 1.00000000e+00, 5.95783685e-02, ...,
#         1.20553360e-01, 3.06661461e-03, 4.12564327e-01],
#        [4.49438202e-01, 1.00000000e+00, 3.48304308e-02, ...,
#         8.06324111e-01, 1.82828960e-02, 3.47606564e-02],
#        [4.15730337e-01, 1.00000000e+00, 6.78276810e-02, ...,
#         1.95652174e-01, 1.68743889e-01, 1.71764249e-01]])

# %%
def training(model, name, axes):
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    score = accuracy_score(y_test, pred)
    report = classification_report(y_test, pred)
    cm = confusion_matrix(y_test, pred)
    sns.heatmap(cm, annot=True, ax=axes)
    axes.set_title("{}: {}%".format(name, round(score*100, 2)))
    return score*100, report

# %%
rfc = RandomForestClassifier()
etc = ExtraTreesClassifier()
gbc = GradientBoostingClassifier()
abc = AdaBoostClassifier()
lgr = LogisticRegression()
xgb = XGBClassifier()


models = [rfc, etc, gbc, abc, lgr, xgb]
names = ["Random Forest", "Extra Trees", "Gradient Boosting",
        "Ada Boost", "Logistic Regression", "XGBoost"]

# %%
reports, scores = [], []
fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(10, 7))
index = 0
for i in range(2):
    for j in range(3):
        score, report = training(models[index], names[index], axes[i][j])
        scores += [score]
        reports += [report]
        index += 1
plt.tight_layout()
plt.show()

# %%
dt = pd.DataFrame({"scores": scores}, index=names)
dt = dt.sort_values("scores", ascending=False)
dt["scores"] = round(dt["scores"], 2)
fig, axes = plt.subplots()
sns.barplot(x=dt.index, y=dt.iloc[:, 0], ax=axes)
for container in axes.containers:
    axes.bar_label(container)
axes.set_xticklabels(axes.get_xticklabels(), rotation=90)
plt.show()
# Out:
# <ipython-input-76-9d5c533d6c49>:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   axes.set_xticklabels(axes.get_xticklabels(), rotation=90)

# %%
for i, j in zip(names, reports):
    print("*******"*10)
    print(i)
    print(j)
    print("\n\n")
# Out:
# **********************************************************************
# Random Forest
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98       101
#            1       0.98      0.99      0.98       163
#
#     accuracy                           0.98       264
#    macro avg       0.98      0.98      0.98       264
# weighted avg       0.98      0.98      0.98       264
#
#
#
#
# **********************************************************************
# Extra Trees
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87       101
#            1       0.90      0.95      0.93       163
#
#     accuracy                           0.91       264
#    macro avg       0.91      0.89      0.90       264
# weighted avg       0.91      0.91      0.90       264
#
#
#
#
# **********************************************************************
# Gradient Boosting
# ...

# %%
data = datos.iloc[:, :-1].values
data_y = datos.iloc[: ,-1].values
data_y
# Out:
# array([0, 1, 0, ..., 1, 1, 1])

# %%
escalador = preprocessing.MinMaxScaler()
data = escalador.fit_transform(data)
data
# Out:
# array([[5.50561798e-01, 1.00000000e+00, 4.21631531e-02, ...,
#         2.47035573e-01, 4.93528075e-03, 1.06806486e-03],
#        [6.74157303e-02, 1.00000000e+00, 6.78276810e-02, ...,
#         5.15810277e-01, 2.14529547e-02, 1.02825517e-01],
#        [4.71910112e-01, 1.00000000e+00, 4.03299725e-02, ...,
#         4.64426877e-01, 5.56929248e-03, 1.94193611e-04],
#        ...,
#        [3.48314607e-01, 1.00000000e+00, 5.95783685e-02, ...,
#         1.20553360e-01, 3.06661461e-03, 4.12564327e-01],
#        [4.49438202e-01, 1.00000000e+00, 3.48304308e-02, ...,
#         8.06324111e-01, 1.82828960e-02, 3.47606564e-02],
#        [4.15730337e-01, 1.00000000e+00, 6.78276810e-02, ...,
#         1.95652174e-01, 1.68743889e-01, 1.71764249e-01]])

# %%
data_train, data_test, data_y_train, data_y_test = train_test_split(data, data_y, random_state=42, test_size=0.2)

# %%
clasificador = KNeighborsClassifier(n_neighbors=5)
clasificador.fit(data_train, data_y_train)
# Out:
# KNeighborsClassifier()

# %%
prediccion = clasificador.fit(data_train, data_y_train).predict(data_test)
precicion = accuracy_score(data_y_test, prediccion)
classreport = classification_report(data_y_test, prediccion)
conmatrix = confusion_matrix(data_y_test, prediccion)

# %%
precicion
# Out:
# 0.6477272727272727

# %%
print(classreport)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.54      0.54      0.54       101
#            1       0.72      0.71      0.71       163
#
#     accuracy                           0.65       264
#    macro avg       0.63      0.63      0.63       264
# weighted avg       0.65      0.65      0.65       264
